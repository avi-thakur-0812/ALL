# %% [markdown]
# ## Acute Lymphoblastic Leukemia Detection
# Acute Lymphobastic Leukemia (ALL) is a cancer of the bone marrow and blood, which progresses rapidly without treatment.
#
# The diagnosis of ALL is extremely time-consuming, expensive and difficult.
#
# The use of Peripheral Blood Smear(PBS) for an initial screening of patients, would go a long way, especially in areas with economic difficulties and lack of good medical care. Additionally, these areas generally show a lack of accomplished medical personnel, leading to errors while analyzing PBS images.
#
# Hence, a viable solution is to create a classification model trained on more than 3000 images to predict if cells are malignant or benign.
#
#
#
# DISCLAIMER: This is an experimental project, NOT to be used professionally in any way, shape or form.

# %% [markdown]
# # Table of Contents
#
# 1. Importing Necessary Libraries
# 2. The Dataset
# 3. Splitting of Data
# 4. Devices
# 5. Base Class
# 6. The Model
# 7. Outputs and Training
# 8. Analysis and Testing
# 9. Conclusion

# %% [markdown]
# # Importing Necessary Libraries
#
# We proceed to import our required libraries, starting from PyTorch, its neural networks, optimization functions, libraries to handle data loading, images, splitting function etc.
#
# We use inline Matplotlib to illustrate our data.

# %%
# !pip install opendatasets --upgrade --quiet

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.utils import save_image
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
import opendatasets as od
from torch.utils.data import random_split

from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset_url = 'https://www.kaggle.com/datasets/mohammadamireshraghi/blood-cell-cancer-all-4class'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: avithakur0812
# Your Kaggle Key: ··········
# Downloading blood-cell-cancer-all-4class.zip to ./blood-cell-cancer-all-4class
# 100%|██████████| 1.68G/1.68G [01:04<00:00, 27.9MB/s]

# %%
import os

DATA_DIR = './blood-cell-cancer-all-4class'
DATA_DIR = DATA_DIR + '/Blood cell Cancer [ALL]'
print(os.listdir(DATA_DIR))
# Out:
# ['[Malignant] early Pre-B', '[Malignant] Pro-B', '[Malignant] Pre-B', 'Benign']

# %% [markdown]
# # The Dataset
# The dataset contains 4 classes. There's 'Benign', meaning that these groups of cells do not pose any immediate threat of growing and spreading. Malignant cells are the exact opposite and are divided into three parts, '[Malignant] Pro-B', '[Malignant] Pre-B' and '[Malignant] early Pre-B'.
#
# We look at some example images, and analyse the number of images for each class.

# %%
print(os.listdir(DATA_DIR+'/Benign')[:10])
# Out:
# ['Snap_151.jpg', 'Snap_020 (3).jpg', 'Snap_106 (2).jpg', 'Snap_101 (3).jpg', 'Snap_134 (2).jpg', 'Snap_127 (2).jpg', 'Snap_082 (3).jpg', 'Snap_007 (2).jpg', 'Snap_051 (2).jpg', 'Snap_117 (2).jpg']

# %%
ben = len(os.listdir(DATA_DIR+'/Benign'))
pro = len(os.listdir(DATA_DIR+'/[Malignant] Pro-B'))
pre = len(os.listdir(DATA_DIR+'/[Malignant] Pre-B'))
early = len(os.listdir(DATA_DIR+'/[Malignant] early Pre-B'))
print(ben, pro, pre, early)
# Out:
# 512 796 955 979

# %%
sample = (DATA_DIR + '/Blood cell Cancer [ALL]/Benign')[0]

# %%
image_files = os.listdir(DATA_DIR)

# %%
image_size = 64
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
dataset = ImageFolder(root=DATA_DIR, transform=T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(*stats)]))

# %%
class_names = dataset.classes
class_counts = ben, pre, pro, early
plt.bar(class_names, class_counts)
plt.xlabel('Categories')
plt.ylabel('Number of Images')
plt.title('Number of Images in Each Categories')
plt.show()

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3242
#     Root location: ./blood-cell-cancer-all-4class/Blood cell Cancer [ALL]
#     StandardTransform
# Transform: Compose(
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=warn)
#                CenterCrop(size=(64, 64))
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %% [markdown]
# The dataset consists of 3242 images in .jpg format.

# %%
train_size = int(0.9 * len(dataset))  # 90% for training
test_size = len(dataset) - train_size  # Remaining 10% for testing
train_ds1, test_ds = torch.utils.data.random_split(dataset, [train_size, test_size])
train_size
# Out:
# 2917

# %% [markdown]
# #Splitting of Data
# 10% of the images are set apart as the testing dataset, while the rest of the 90% is used for training, but not really, because of the 90%, around 10% which equate to around 300 images, are used for the validation dataset.

# %%
random_seed = 1
torch.manual_seed(random_seed);
val_size = 300
train_size = len(train_ds1) - val_size

train_ds, val_ds = random_split(train_ds1, [train_size, val_size])
len(train_ds), len(val_ds)
# Out:
# (2617, 300)

# %%
#Using the DataLoader to load all our datasets
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_ds, batch_size, shuffle=False, num_workers=3, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
train_ds[0][0].shape
# Out:
# torch.Size([3, 64, 64])

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %% [markdown]
# # Devices
#
# We check if a GPU is available. The model isn't very exhaustive, but a GPU still saves time. It takes around 10 minutes to train, while a CPU does it in around half an hour.
#
# We then load our data to the device.

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# #Base Class
#
# Our base class extends the nn.Module class, and defines training and validation steps. It generates predictions, calculates losses and accuracies, and combines them at the end of epochs.

# %%
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}".format( epoch, result['train_loss']))
        
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# #The Model
# We create our working model by extending the previously defined base class.
#
# It is comprised of a series of Convolutional Neural Networks, Batch Normalizing layers, activation functions and pooling layers.
#
# Our input is a 3 channel RGB image, we convolve with a default stride and padding of 1, and a kernel of 3x3. The convolutions happen sequentially and convert the channels into a linear output over time, and many layers.
#
# Batch Normalization is extremely useful, as it solves the problem of internal covariate shift. As we update individual nodes using our error function, we assume that other layers, are constant, ignoring the fact that all layers are continuously changing. Hence, to prevent overfitting, we normalize individual batches using their mean and variance.
#
# We use the LeakyReLU, allowing the passage of a small negative value as the activation function to ensure that our Neural Network undesrtands the non-linear relationships.
#
# Finally, the Max Pooling layer compresses the data.

# %%
class ALLClassifier(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            nn.MaxPool2d(2, 2), 
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.MaxPool2d(2, 2), 

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.MaxPool2d(2, 2),

            nn.Flatten(), 
            nn.Linear(256*8*8, 1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 4)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
to_device(model, device);

# %%
model = ALLClassifier()
model
# Out:
# ALLClassifier(
#   (network): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): LeakyReLU(negative_slope=0.2, inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.2, inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.2, inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): LeakyReLU(negative_slope=0.2, inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Flatten(start_dim=1, end_dim=-1)
#     (22): Linear(in_features=16384, out_features=1024, bias=True)
#     (23): LeakyReLU(negative_slope=0.2, inplace=True)
#     (24): Linear(in_features=1024, out_features=512, bias=True)
#     (25): LeakyReLU(negative_slope=0.2, inplace=True)
#     (26): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
for images, labels in train_dl:
    print('images.shape:', images.shape)
    out = model(images)
    print('out.shape:', out.shape)
    print('out[0]:', out[0])
    break
# Out:
# images.shape: torch.Size([128, 3, 64, 64])
# out.shape: torch.Size([128, 4])
# out[0]: tensor([ 0.0414, -0.0693, -0.0035,  0.0152], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# # Outputs and Training
# The output is of the shape (128, 4), representing the 4 classes of our dataset.
#
# We can now proceed to define functions to train out model, and record the training and validation data.
# We train our dataset for 10 epochs, with a relatively low learning rate using the Adam Optimizer.

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
model = to_device(ALLClassifier(), device)

# %%
num_epochs = 10
opt_func = torch.optim.Adam
lr = 0.001

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 3.2619
# Epoch [1], train_loss: 0.7396
# Epoch [2], train_loss: 0.4259
# Epoch [3], train_loss: 0.2804
# Epoch [4], train_loss: 0.2554
# Epoch [5], train_loss: 0.1401
# Epoch [6], train_loss: 0.1194
# Epoch [7], train_loss: 0.1002
# Epoch [8], train_loss: 0.0799
# Epoch [9], train_loss: 0.0501

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %% [markdown]
# # Analysis and Testing
# We plot the accuracy and losses to get to grips with the performance of our model.
#
# We then test our model against some random images.
#
# Finally, we evaluate our models against the test dataset.

# %%
plot_accuracies(history)

# %%
plot_losses(history)

# %% [markdown]
# The graph above clearly shows that we're starting to overfit the data, so it might be better to exit early, as the validation error starts climbing up, while the training error remains almost constant.

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %%
img, label = test_ds[100]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: [Malignant] early Pre-B , Predicted: [Malignant] early Pre-B

# %%
img, label = test_ds[40]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: [Malignant] Pro-B , Predicted: [Malignant] Pro-B

# %%
img, label = test_ds[1]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: [Malignant] Pro-B , Predicted: [Malignant] Pro-B

# %%
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

# %%
result = evaluate(model, test_dl)
result
# Out:
# {'val_loss': 0.05807952210307121, 'val_acc': 0.9873566031455994}

# %% [markdown]
# We evaluate the model with the test dataset.
# Our model ends up with a very respectable accuracy of around 98%
#
# But it is to be noted that, retraining the model has an affect on accuracy, it can range anywhere from 95% to 99%.
#
# The selection of hyperparameters in conjuction with the architecture of the model,has helped in reaching a high accuracy.

# %%
# !pip install jovian --upgrade --quiet
import jovian
jovian.reset()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for uuid (setup.py) ... done

# %%
jovian.log_hyperparams(lr=lr, epochs=num_epochs)
# Out:
# [jovian] Please enter your API key ( from https://jovian.com/ ):
# API KEY: ··········
# [jovian] Hyperparams logged.

# %%
torch.save(model.state_dict(), 'model_weights.pth')

# %% [markdown]
# # Conclusion
#
# In conclusion, we successfully trained a model using knowledge of the various concepts learnt throughout the course.
#
# The medical field is extremely important for us as a society, and any work in improving the current technologies, making them more affordable and accessable is the need of the hour. This was my motivation as I started this project.
#
# The model ended up with a great accuracy, due to the correct usage of batch normalization, pooling layers, activation functions. Maybe, with more tinkering of the hyperparameters and further improvement of the architecture, the model can be made even more accurate.
#
# But, all things considered, it might be a better idea to experiment with stable diffussion for this sort of problem, as it is faster and a lot mroe accurate.
